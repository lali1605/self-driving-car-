# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/vibrometerdataset/16_4_9.CSV
# /kaggle/input/vibrometerdataset/data ml.csv

# %%
import pandas as pd 
files1 = pd.read_csv('../input/vibrometerdataset/data ml.csv')
print(files1)
a =files1.info
b = files1.dropna()
print(b)
# Out:
#      -1.220703125  -4.9
# 0       -1.228220  -4.9
# 1       -1.229000  -4.9
# 2       -1.221060  -4.9
# 3       -1.221180  -4.9
# 4       -1.221299  -4.9
# ..            ...   ...
# 144     -1.238236   5.0
# 145     -1.238359   5.0
# 146     -1.238482   4.9
# 147           NaN   NaN
# 148           NaN   NaN
#
# [149 rows x 2 columns]
#      -1.220703125  -4.9
# 0       -1.228220  -4.9
# 1       -1.229000  -4.9
# 2       -1.221060  -4.9
# 3       -1.221180  -4.9
# 4       -1.221299  -4.9
# ..            ...   ...
# 142     -1.237991   5.0
# 143     -1.238114   4.9
# 144     -1.238236   5.0
# 145     -1.238359   5.0
# 146     -1.238482   4.9
#
# [147 rows x 2 columns]

# %%
x = b.iloc[:,0].values
y = b.iloc[:,1].values
print(x)
print(y)
# Out:
# [-1.22822    -1.229      -1.22106    -1.22118    -1.221299   -1.22141
#  -1.221538   -1.221657   -1.2217769  -1.221896   -1.222015   -1.222135
#  -1.2222548  -1.222374   -1.222493   -1.2226134  -1.222733   -1.2228526
#  -1.222972   -1.223091   -1.223211   -1.223331   -1.22345    -1.22357
#  -1.22369    -1.22381    -1.22393    -1.22405    -1.22417    -1.224289
#  -1.224409   -1.224529   -1.22464    -1.22476    -1.2248889  -1.2250098
#  -1.225129   -1.225249   -1.22537    -1.22549    -1.2256103  -1.22573
#  -1.22585    -1.22597    -1.226091   -1.226211   -1.226331   -1.226452
#  -1.22657    -1.226692   -1.226813   -1.226933   -1.227054   -1.227174
#  -1.227295   -1.22741    -1.227536   -1.2276566  -1.2277772  -1.227898
#  -1.228018   -1.22813    -1.22825    -1.22838    -1.228501   -1.2286219
#  -1.22874275 -1.22886    -1.228984   -1.229105   -1.229226   -1.229211
#  -1.22946    -1.229588   -1.229709   -1.22983    -1.229951   -1.230072
# ...

# %%
#regr.fit(x_train,y_train)

# %%
import matplotlib.pyplot as plt #for graph plotting of x, y
import numpy as np #for using data as an array 
from sklearn import datasets, linear_model #for the model we wish to predict by 
import pandas as pd #for loading csv file data to numpy array 
from sklearn.metrics import mean_squared_error, r2_score #for mean error and variance calculations 
from sklearn.model_selection import train_test_split #splitting training and testing sets 
x_train , y_train , x_test , y_test = train_test_split(x,y,test_size = 1/4,random_state=0)

# %%
from sklearn.model_selection import train_test_split #splitting training and testing sets 
x_train , y_train , x_test , y_test = train_test_split(x,y,test_size = 1/4,random_state=0)
x_test = x_test.reshape(-1, 1)
x_train = x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
regr = linear_model.LinearRegression()
print(regr)
# Out:
# LinearRegression()

# %%
print(x_train)
print(y_train)
# Out:
# [[-1.222015  ]
#  [-1.2367665 ]
#  [-1.233714  ]
#  [-1.227898  ]
#  [-1.23408   ]
#  [-1.22813   ]
#  [-1.229588  ]
#  [-1.23566627]
#  [-1.237501  ]
#  [-1.234567  ]
#  [-1.232498  ]
#  [-1.232134  ]
#  [-1.228018  ]
#  [-1.224409  ]
#  [-1.227536  ]
#  [-1.231041  ]
#  [-1.236521  ]
#  [-1.2359106 ]
#  [-1.235177  ]
#  [-1.2318911 ]
#  [-1.23481181]
#  [-1.22657   ]
#  [-1.237868  ]
#  [-1.232863  ]
#  [-1.222374  ]
#  [-1.22874275]
#  [-1.2328996 ]
#  [-1.2311632 ]
#  [-1.236155  ]
#  [-1.2226134 ]
#  [-1.227054  ]
#  [-1.22118   ]
#  [-1.23542202]
#  [-1.236399  ]
#  [-1.221538  ]
#  [-1.228984  ]
#  [-1.23701138]
#  [-1.2222548 ]
#  [-1.230126  ]
#  [-1.23420221]
#  [-1.23225552]
#  [-1.226331  ]
#  [-1.222135  ]
#  [-1.232984  ]
#  [-1.23359   ]
#  [-1.22573   ]
#  [-1.233836  ]
#  [-1.229     ]
#  [-1.233349  ]
#  [-1.237256  ]
#  [-1.22585   ]
#  [-1.221299  ]
#  [-1.23554413]
#  [-1.2228526 ]
#  [-1.22537   ]
#  [-1.22141   ]
#  [-1.227174  ]
#  [-1.2377463 ]
# ...

# %%
import pandas as pd 
p = b.iloc[:-2]
print(p)
# Out:
#      -1.220703125  -4.9
# 0       -1.228220  -4.9
# 1       -1.229000  -4.9
# 2       -1.221060  -4.9
# 3       -1.221180  -4.9
# 4       -1.221299  -4.9
# ..            ...   ...
# 140     -1.237746   4.9
# 141     -1.237868   5.0
# 142     -1.237991   5.0
# 143     -1.238114   4.9
# 144     -1.238236   5.0
#
# [145 rows x 2 columns]

# %%
print(x_train)
print(y_train)
# Out:
# [[-1.222015  ]
#  [-1.2367665 ]
#  [-1.233714  ]
#  [-1.227898  ]
#  [-1.23408   ]
#  [-1.22813   ]
#  [-1.229588  ]
#  [-1.23566627]
#  [-1.237501  ]
#  [-1.234567  ]
#  [-1.232498  ]
#  [-1.232134  ]
#  [-1.228018  ]
#  [-1.224409  ]
#  [-1.227536  ]
#  [-1.231041  ]
#  [-1.236521  ]
#  [-1.2359106 ]
#  [-1.235177  ]
#  [-1.2318911 ]
#  [-1.23481181]
#  [-1.22657   ]
#  [-1.237868  ]
#  [-1.232863  ]
#  [-1.222374  ]
#  [-1.22874275]
#  [-1.2328996 ]
#  [-1.2311632 ]
#  [-1.236155  ]
#  [-1.2226134 ]
#  [-1.227054  ]
#  [-1.22118   ]
#  [-1.23542202]
#  [-1.236399  ]
#  [-1.221538  ]
#  [-1.228984  ]
#  [-1.23701138]
#  [-1.2222548 ]
#  [-1.230126  ]
#  [-1.23420221]
#  [-1.23225552]
#  [-1.226331  ]
#  [-1.222135  ]
#  [-1.232984  ]
#  [-1.23359   ]
#  [-1.22573   ]
#  [-1.233836  ]
#  [-1.229     ]
#  [-1.233349  ]
#  [-1.237256  ]
#  [-1.22585   ]
#  [-1.221299  ]
#  [-1.23554413]
#  [-1.2228526 ]
#  [-1.22537   ]
#  [-1.22141   ]
#  [-1.227174  ]
#  [-1.2377463 ]
# ...

# %% [markdown]
# ## Import packages to visualize the classifer
# from matplotlib.colors import ListedColormap
# import matplotlib.pyplot as plt
# import warnings
#
# # Import packages to do the classifying
# import numpy as np
# from sklearn.svm import SVC
#
# # Create Dataset
# np.random.seed(0)
# X_xor = np.random.randn(200, 2)
# y_xor = np.logical_xor(X_xor[:, 0] > 0,
#                        X_xor[:, 1] > 0)
# y_xor = np.where(y_xor, 1, -1)
#
# fig = plt.figure(figsize=(10,10))
# plt.scatter(X_xor[y_xor == 1, 0],
#             X_xor[y_xor == 1, 1],
#             c='b', marker='x',
#             label='1')
# plt.scatter(X_xor[y_xor == -1, 0],
#             X_xor[y_xor == -1, 1],
#             c='r',
#             marker='s',
#             label='-1')
#
# plt.xlim([-3, 3])
# plt.ylim([-3, 3])
# plt.legend(loc='best')
# plt.tight_layout()
# plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd 
b = pd.read_csv('../input/vibrometerdataset/data ml.csv')
print(files1)
t_n = 10
N = 1000
T = t_n / N
f_s = 1/T
 
x_value = np.linspace(0,t_n)
amplitudes = y
frequencies = x
y_values = [amplitudes[ii]*np.sin(2*np.pi*frequencies[ii]*x_value) for ii in range(0,len(amplitudes))]
composite_y_value = np.sum(y_values, axis=0)
get_fft_values = 0  
#f_values, fft_values =get_fft_values(composite_y_value, T, N, f_s)
 
#colors = [red,green,cyan]
 
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("\nTime [s]", fontsize=16)
ax.set_ylabel("\nFrequency [Hz]", fontsize=16)
ax.set_zlabel("\nAmplitude", fontsize=16)
 
y_values_ = [composite_y_value] + list(reversed(y_values))
frequencies = x
 
for ii in range(0,len(y_values_)):
    signal = y_values_[ii]
    #color = colors[ii]
    length = signal.shape[0]
    x=np.linspace(0,10,1000)
    y=np.array([frequencies[ii]]*length)
    z=signal
 
    if ii == 0:
        linewidth = 4
    else:
        linewidth = 2
    ax.plot(list(x), list(y), zs=list(z), linewidth=linewidth ,color = color)
 
    x=[10]*75
    y=fft_values[:75]
    z = f_values[:75]*3
    ax.plot(list(x), list(y), zs=list(z), linewidth=2, color='red')
    
    plt.tight_layout()
plt.show()
# Out:
#      -1.220703125  -4.9
# 0       -1.228220  -4.9
# 1       -1.229000  -4.9
# 2       -1.221060  -4.9
# 3       -1.221180  -4.9
# 4       -1.221299  -4.9
# ..            ...   ...
# 144     -1.238236   5.0
# 145     -1.238359   5.0
# 146     -1.238482   4.9
# 147           NaN   NaN
# 148           NaN   NaN
#
# [149 rows x 2 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/827685613.py in <module>
#      39     else:
#      40         linewidth = 2
# ---> 41     ax.plot(list(x), list(y), zs=list(z), linewidth=linewidth ,color = color)
#      42
#      43     x=[10]*75
#
# NameError: name 'color' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
print(b)

# %%
#k = b.reshape(-1,1)
#svc = svm.SVC(kernel='rbf', C=1).fit(X, y)

# %%
model.fit(x_train, y_train)

# %%
import numpy as np

import matplotlib.pyplot as plot

 
a = float(input("enter the  : "))
b = float(input("enter the  : "))
# Get x values of the sine wave

#time        = np.arange(0, 10, 0.1);
time = np.arange(b,a,0.1)

 

# Amplitude of the sine wave is sine of a variable like time

amplitude   = np.sin(time)

 

# Plot a sine wave using time and amplitude obtained for the sine wave

plot.plot(time, amplitude )


 

# Give a title for the sine wave plot

plot.title('Sine wave')


 

# Give x axis label for the sine wave plot

plot.xlabel('Time')
#plot.xlabel('frequency')

 

# Give y axis label for the sine wave plot

plot.ylabel('Amplitude = sin(time)')


 

plot.grid(True, which='both')

 

plot.axhline(y=0, color='k')

 

plot.show()

 

# Display the sine wave

plot.show()
# Out:
# enter the  :  1.3
# enter the  :  2.4

# %%
# [X - t(time)], [V(velocity) - t(time)], [a(acceleration) - t(time)] 
#[X - t(time)] 

import numpy as np

from matplotlib import pyplot as plt

# mx'' = - bx' - kx

x_0 = -23.4

v_0 = -23.6

y_0 = np.array([x_0,v_0])         # first array 


def Euler_Method(f,a,b,y0,step):

  t = np.linspace(a,b,step)

  h = t[1] - t[0]

  Y = [y0]

  N = len(t)

  n = 0

  y = y0

  for n in range(0,N-1) :

    y = y + h*f(y,t[n])

    Y.append(y)

    n = n+1  

  Y = np.array(Y)

  return Y, t




def harmonic(y,t) :

  k = 50

  m = 200

  b = 20  # drag coefficient

  a = (-1*k/m)*y[0] - (b/m)*y[1]   # x'' = a,  y[0] : first position

  v = y[1]                         # v = first velocity : y[1]

  f = np.array([v,a])

  return f

  


a = Euler_Method(harmonic, 0, 900, y_0, 1000)
b = Euler_Method(harmonic, -20, 68, y_0, 1000) #

X = a[0][:,0]
Y = b[0][:,1] #
t = a[1]
t2= b[-1] #

plt.plot(t,X)
plt.plot(t2,Y)

plot.xlabel('Time')
plot.ylabel('time Amplitude')


plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plot

#a = float(input("enter value of a :"  )) 
#b = float(input("enter the value of b :" ))

# Get x values of the sine wave
time        =  np.arange(0,1.288 , 0.001);
amplitude   = np.sin(time)
print(amplitude)
plot.plot(frequency, amplitude)

plot.title('Vibration plot')

plot.xlabel('time')

plot.ylabel('amplitude')
# Out:
# [0.         0.001      0.002      ... 0.95943746 0.9597189  0.95999938]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/4231410275.py in <module>
#      10 amplitude   = np.sin(time)
#      11 print(amplitude)
# ---> 12 plot.plot(frequency, amplitude)
#      13
#      14 plot.title('Vibration plot')
#
# NameError: name 'frequency' is not defined

# %%
import pandas as pd
df = pd.read_csv('../input/vibrometerdataset/16_4_9.CSV', 
                 delimiter=',', parse_dates=[1])
df.rename(columns={'Seconds':'Seconds',
                   'volts':'volts'},
          inplace=True)
print(df)
# Out:
#        Seconds  volts
# 0      -0.81912  -9.8
# 1      -0.81904  -9.8
# 2      -0.81896  -9.8
# 3      -0.81888  -9.8
# 4      -0.81880  -9.8
# ...         ...   ...
# 20474   0.81880    10
# 20475   0.81888    10
# 20476   0.81896    10
# 20477   0.81904   9.8
# 20478   0.81912   9.8
#
# [20479 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 6))
plt.plot( df['volts'])
plt.xlabel('Seconds')
plt.ylabel('volts')
plt.xticks(rotation=25) 

plt.show()

# %%
from numpy.fft import fft, ifft
from scipy.fftpack import fft, ifft
X = fft(x)
N = len(X)
n = np.arange(N)
T = N/sr
freq = n/T 

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0, 10)

plt.subplot(122)
plt.plot(t, ifft(X), 'r')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/605063220.py in <module>
#       4 N = len(X)
#       5 n = np.arange(N)
# ----> 6 T = N/sr
#       7 freq = n/T
#       8
#
# NameError: name 'sr' is not defined

# %%
from scipy.fftpack import fft, ifft
X = fft(df['volts'])
N = len(X)
n = np.arange(N)
# get the sampling rate
sr = 1 / (60*60)
T = N/sr
freq = n/T 

# Get the one-sided specturm
n_oneside = N//2
# get the one side frequency
f_oneside = freq[:n_oneside]

plt.figure(figsize = (12, 6))
plt.plot(f_oneside, np.abs(X[:n_oneside]), 'b')
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-poster')
# %matplotlib inline

# %%
# sampling rate
sr = 2000
# sampling interval
ts = 1.0/sr
t = np.arange(0,1,ts)

freq = float(input("enter the frequency: "))
x = 3*np.sin(2*np.pi*freq*t)

freq = 4
x += np.sin(2*np.pi*freq*t)

freq = 7   
x += 0.5* np.sin(2*np.pi*freq*t)

plt.figure(figsize = (8, 6))
plt.plot(t, x, 'r')
plt.ylabel('Amplitude')

plt.show()

# %%
from numpy.fft import fft, ifft

X = fft(x)
N = len(X)
n = np.arange(N)
T = N/sr
freq = n/T 

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0, 10)

plt.subplot(122)
plt.plot(t, ifft(X), 'r')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()

# %%
# %timeit fft(x)

# %%
import pandas as pd

# %%
df = pd.read_csv('../input/vibrometerdataset/16_4_9.CSV', 
                 delimiter=',', parse_dates=[1])
df.rename(columns={'Seconds':'Seconds',
                   'volts':'volts'},
          inplace=True)
print(df)

# %%
plt.figure(figsize = (12, 6))
#plt.plot(df[Seconds], df[volts])
plt.plot(df['volts'])
plt.xlabel('Seconds')
plt.ylabel('volts')
plt.xticks(rotation=25) 
plt.show()

# %%
X = fft(df['volts'])
N = len(X)
n = np.arange(N)
# get the sampling rate
sr = 1 / (60*60)
T = N/sr
freq = n/T 

# Get the one-sided specturm
n_oneside = N//2
# get the one side frequency
f_oneside = freq[:n_oneside]

plt.figure(figsize = (12, 6))
plt.plot(f_oneside, np.abs(X[:n_oneside]), 'b')
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.show()

# %%
# convert frequency to hour
t_h = 1/f_oneside / (60 * 60)

plt.figure(figsize=(12,6))
plt.plot(t_h, np.abs(X[:n_oneside])/n_oneside)
plt.xticks([100,200,300,400])
plt.xlim(0, 200)
plt.xlabel('Period ($hour$)')
plt.show()
